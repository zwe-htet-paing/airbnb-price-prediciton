# %%
import pandas as pd
import numpy as np

import pickle

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import root_mean_squared_error

import warnings
warnings.filterwarnings("ignore")

# %%
import mlflow

# `mlflow ui --backend-store-uri sqlite:///mlflow.db`
mlflow.set_tracking_uri("sqlite:///mlflow.db")


# `mlflow server --backend-store-uri sqlite:///mlflow.db`
# mlflow.set_tracking_uri("http://127.0.0.1:5000")

print(f"tracking URI: '{mlflow.get_tracking_uri()}'")
# Out:
# tracking URI: 'sqlite:///mlflow.db'

# %%
def read_dataframe(filename):
    df = pd.read_csv(filename)
    df.drop(['host_id','name','latitude','longitude','id','host_name','last_review', 'neighbourhood_group', 'license'], axis=1, inplace=True)
    df.dropna(subset=['price'], inplace=True)
    df.reset_index(drop=True, inplace=True)
    df['reviews_per_month'] = df['reviews_per_month'].fillna(0)
    
    df = df[df["price"]<201]
    df = df[df["price"]>0]
    
    # Feature selection
    categorical = ['room_type', 'neighbourhood']
    df[categorical] = df[categorical].astype(str)

    return df

# %%
df_train = read_dataframe("datasets/airbnb-listings-may.csv")
df_val = read_dataframe("datasets/airbnb-listings-june.csv")

# %%
len(df_train), len(df_val)
# Out:
# (315, 334)

# %%
# Feature selection
numerical = ['minimum_nights', 'number_of_reviews', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'number_of_reviews_ltm']
categorical = ['room_type', 'neighbourhood']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = "price"
y_train = df_train[target].values
y_val = df_val[target].values

# %% [markdown]
# ### LinearRegression

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

root_mean_squared_error(y_val, y_pred)
# Out:
# 32.50037412768117

# %%
sns.distplot(y_pred, label='prediction')
sns.distplot(y_train, label='actual')

plt.legend()

# %%
mlflow.set_experiment("airbnb-experiment")
mlflow.sklearn.autolog()

with mlflow.start_run():

    mlflow.set_tag("developer", "oliver")
    mlflow.log_param("train-data-path", "datasets/airbnb-listings-may.csv")
    mlflow.log_param("val-data-path", "datasets/airbnb-listings-june.csv")
    
    lr = LinearRegression()
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)
    rmse = root_mean_squared_error(y_val, y_pred)
    mlflow.log_metric("rmse", rmse)
    
    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)
    mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

    with open("models/lin_reg.bin", "wb") as f_out:
        pickle.dump(lr, f_out)
    mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models_pickle")
# Out:
# 2024/07/28 18:29:07 INFO mlflow.tracking.fluent: Experiment with name 'airbnb-experiment' does not exist. Creating a new experiment.
# 2024/07/28 18:29:07 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of sklearn. If you encounter errors during autologging, try upgrading / downgrading sklearn to a supported version, or try upgrading MLflow.
# 2024/07/28 18:29:08 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'

# %% [markdown]
# ### XGBoost

# %%
import xgboost as xgb
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = root_mean_squared_error(y_val, y_pred)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
# [0]	validation-rmse:29.50105
# [1]	validation-rmse:29.79577
# [2]	validation-rmse:29.56101
# [3]	validation-rmse:28.62318
# [4]	validation-rmse:28.35727
# [5]	validation-rmse:28.39886
# [6]	validation-rmse:27.39796
# [7]	validation-rmse:27.38703
# [8]	validation-rmse:27.71683
# [9]	validation-rmse:27.80596
# [10]	validation-rmse:27.49299
# [11]	validation-rmse:27.51790
# [12]	validation-rmse:27.57519
# [13]	validation-rmse:27.83820
# [14]	validation-rmse:27.91941
# [15]	validation-rmse:28.18064
# [16]	validation-rmse:28.29649
# [17]	validation-rmse:28.13396
# [18]	validation-rmse:28.12265
# [19]	validation-rmse:28.18928
# [20]	validation-rmse:28.05390
# [21]	validation-rmse:27.93291
# [22]	validation-rmse:28.04861
# [23]	validation-rmse:28.04278
# [24]	validation-rmse:28.06783
# [25]	validation-rmse:28.06754
# [26]	validation-rmse:28.14348
# [27]	validation-rmse:28.13141
# [28]	validation-rmse:28.12325
# [29]	validation-rmse:28.14786
# [30]	validation-rmse:28.14401
# [31]	validation-rmse:28.19784
# [32]	validation-rmse:28.17368
# [33]	validation-rmse:28.24388
# [34]	validation-rmse:28.20465
# [35]	validation-rmse:28.19287
# [36]	validation-rmse:28.23415
# [37]	validation-rmse:28.22033
# [38]	validation-rmse:28.23321
# [39]	validation-rmse:28.16433
# [40]	validation-rmse:28.21268
# [41]	validation-rmse:28.28260
# [42]	validation-rmse:28.23950
# [43]	validation-rmse:28.17591
# [44]	validation-rmse:28.20411
# [45]	validation-rmse:28.18905
# [46]	validation-rmse:28.16071
# [47]	validation-rmse:28.19880
# [48]	validation-rmse:28.16979
# [49]	validation-rmse:28.15967
# [50]	validation-rmse:28.17851
# [51]	validation-rmse:28.20688
# [52]	validation-rmse:28.25342
# [53]	validation-rmse:28.23996
# [54]	validation-rmse:28.25037
# [55]	validation-rmse:28.22155
# [56]	validation-rmse:28.24636
# [0]	validation-rmse:32.67727
# [1]	validation-rmse:33.92634
# [2]	validation-rmse:33.17524
# [3]	validation-rmse:33.33571
# [4]	validation-rmse:33.35473
# [5]	validation-rmse:33.37469
# [6]	validation-rmse:33.40436
# [7]	validation-rmse:33.41283
# [8]	validation-rmse:33.40210
# [9]	validation-rmse:33.39166
# [10]	validation-rmse:33.38887
# [11]	validation-rmse:33.38905
# [12]	validation-rmse:33.38914
# [13]	validation-rmse:33.38967
# [14]	validation-rmse:33.38951
# [15]	validation-rmse:33.38927
# [16]	validation-rmse:33.38932
# [17]	validation-rmse:33.38928
# [18]	validation-rmse:33.38927
# [19]	validation-rmse:33.38926
# [20]	validation-rmse:33.38925
# [21]	validation-rmse:33.38925
# [22]	validation-rmse:33.38925
# [23]	validation-rmse:33.38925
# [24]	validation-rmse:33.38925
# [25]	validation-rmse:33.38925
# [26]	validation-rmse:33.38925
# [27]	validation-rmse:33.38925
# [28]	validation-rmse:33.38925
# [29]	validation-rmse:33.38925
# [30]	validation-rmse:33.38925
# [31]	validation-rmse:33.38925
# [32]	validation-rmse:33.38925
# [33]	validation-rmse:33.38925
# [34]	validation-rmse:33.38925
# [35]	validation-rmse:33.38925
# [36]	validation-rmse:33.38925
# [37]	validation-rmse:33.38925
# [38]	validation-rmse:33.38925
# [39]	validation-rmse:33.38925
# [40]	validation-rmse:33.38925
# [41]	validation-rmse:33.38925
# [42]	validation-rmse:33.38925
# [43]	validation-rmse:33.38925
# [44]	validation-rmse:33.38925
# [45]	validation-rmse:33.38925
# [46]	validation-rmse:33.38925
# [47]	validation-rmse:33.38925
# [48]	validation-rmse:33.38925
# [49]	validation-rmse:33.38925
# [50]	validation-rmse:33.38925
# [0]	validation-rmse:36.82418
# [1]	validation-rmse:35.90475
# [2]	validation-rmse:35.07747
# [3]	validation-rmse:34.26454
# [4]	validation-rmse:33.51028
# [5]	validation-rmse:32.83019
# [6]	validation-rmse:32.24050
# [7]	validation-rmse:31.63235
# [8]	validation-rmse:31.17920
# [9]	validation-rmse:30.74534
# [10]	validation-rmse:30.27103
# [11]	validation-rmse:29.85795
# [12]	validation-rmse:29.42119
# [13]	validation-rmse:29.03785
# [14]	validation-rmse:28.77586
# [15]	validation-rmse:28.42507
# [16]	validation-rmse:28.26660
# [17]	validation-rmse:28.03079
# [18]	validation-rmse:27.83907
# [19]	validation-rmse:27.65193
# [20]	validation-rmse:27.50193
# [21]	validation-rmse:27.38114
# [22]	validation-rmse:27.17275
# [23]	validation-rmse:26.98617
# [24]	validation-rmse:26.79647
# [25]	validation-rmse:26.61524
# [26]	validation-rmse:26.52463
# [27]	validation-rmse:26.38584
# [28]	validation-rmse:26.28352
# [29]	validation-rmse:26.17092
# [30]	validation-rmse:26.08261
# [31]	validation-rmse:25.98142
# [32]	validation-rmse:25.90179
# [33]	validation-rmse:25.82527
# [34]	validation-rmse:25.70893
# [35]	validation-rmse:25.60803
# [36]	validation-rmse:25.54007
# [37]	validation-rmse:25.46605
# [38]	validation-rmse:25.42803
# [39]	validation-rmse:25.35583
# [40]	validation-rmse:25.24078
# [41]	validation-rmse:25.20142
# [42]	validation-rmse:25.17504
# [43]	validation-rmse:25.13714
# [44]	validation-rmse:25.09402
# [45]	validation-rmse:25.10114
# [46]	validation-rmse:25.03874
# [47]	validation-rmse:24.98190
# [48]	validation-rmse:24.92484
# [49]	validation-rmse:24.84936
# [50]	validation-rmse:24.78571
# [51]	validation-rmse:24.73800
# [52]	validation-rmse:24.67905
# [53]	validation-rmse:24.62028
# [54]	validation-rmse:24.55737
# [55]	validation-rmse:24.51349
# [56]	validation-rmse:24.48819
# [57]	validation-rmse:24.44348
# [58]	validation-rmse:24.38387
# [59]	validation-rmse:24.32645
# [60]	validation-rmse:24.31591
# [61]	validation-rmse:24.30635
# [62]	validation-rmse:24.25400
# [63]	validation-rmse:24.24256
# [64]	validation-rmse:24.23548
# [65]	validation-rmse:24.22522
# [66]	validation-rmse:24.20282
# [67]	validation-rmse:24.15800
# [68]	validation-rmse:24.13692
# [69]	validation-rmse:24.09323
# [70]	validation-rmse:24.08323
# [71]	validation-rmse:24.04344
# [72]	validation-rmse:24.01757
# [73]	validation-rmse:23.99290
# [74]	validation-rmse:23.98293
# [75]	validation-rmse:23.96714
# [76]	validation-rmse:23.94283
# [77]	validation-rmse:23.90727
# [78]	validation-rmse:23.87296
# [79]	validation-rmse:23.85021
# [80]	validation-rmse:23.82279
# [81]	validation-rmse:23.81017
# [82]	validation-rmse:23.78867
# [83]	validation-rmse:23.79672
# [84]	validation-rmse:23.77939
# [85]	validation-rmse:23.78170
# [86]	validation-rmse:23.76212
# [87]	validation-rmse:23.73812
# [88]	validation-rmse:23.71321
# [89]	validation-rmse:23.68979
# [90]	validation-rmse:23.67197
# [91]	validation-rmse:23.66851
# [92]	validation-rmse:23.66126
# [93]	validation-rmse:23.63006
# [94]	validation-rmse:23.61260
# [95]	validation-rmse:23.59674
# [96]	validation-rmse:23.58103
# [97]	validation-rmse:23.57598
# [98]	validation-rmse:23.56670
# [99]	validation-rmse:23.56747
# [100]	validation-rmse:23.56424
# [101]	validation-rmse:23.55361
# [102]	validation-rmse:23.54862
# [103]	validation-rmse:23.53418
# [104]	validation-rmse:23.51717
# [105]	validation-rmse:23.51194
# [106]	validation-rmse:23.49305
# [107]	validation-rmse:23.49017
# [108]	validation-rmse:23.47768
# [109]	validation-rmse:23.47915
# [110]	validation-rmse:23.46910
# [111]	validation-rmse:23.45177
# [112]	validation-rmse:23.43831
# [113]	validation-rmse:23.42278
# [114]	validation-rmse:23.40828
# [115]	validation-rmse:23.40805
# [116]	validation-rmse:23.38846
# [117]	validation-rmse:23.38393
# [118]	validation-rmse:23.36581
# [119]	validation-rmse:23.35328
# [120]	validation-rmse:23.33624
# [121]	validation-rmse:23.33373
# [122]	validation-rmse:23.33477
# [123]	validation-rmse:23.32652
# [124]	validation-rmse:23.32142
# [125]	validation-rmse:23.31350
# [126]	validation-rmse:23.31061
# [127]	validation-rmse:23.31009
# [128]	validation-rmse:23.30820
# [129]	validation-rmse:23.31153
# [130]	validation-rmse:23.30934
# [131]	validation-rmse:23.31207
# [132]	validation-rmse:23.31411
# [133]	validation-rmse:23.30359
# [134]	validation-rmse:23.30063
# [135]	validation-rmse:23.29018
# [136]	validation-rmse:23.29222
# [137]	validation-rmse:23.28012
# [138]	validation-rmse:23.27978
# [139]	validation-rmse:23.27400
# [140]	validation-rmse:23.26818
# [141]	validation-rmse:23.27181
# [142]	validation-rmse:23.25574
# [143]	validation-rmse:23.25759
# [144]	validation-rmse:23.25368
# [145]	validation-rmse:23.24778
# [146]	validation-rmse:23.25969
# [147]	validation-rmse:23.25725
# [148]	validation-rmse:23.25371
# [149]	validation-rmse:23.24940
# [150]	validation-rmse:23.23588
# [151]	validation-rmse:23.23840
# [152]	validation-rmse:23.24537
# [153]	validation-rmse:23.24457
# [154]	validation-rmse:23.25626
# [155]	validation-rmse:23.25253
# [156]	validation-rmse:23.23858
# [157]	validation-rmse:23.24791
# [158]	validation-rmse:23.24393
# [159]	validation-rmse:23.23077
# [160]	validation-rmse:23.22771
# [161]	validation-rmse:23.22625
# [162]	validation-rmse:23.23001
# [163]	validation-rmse:23.21973
# [164]	validation-rmse:23.21375
# [165]	validation-rmse:23.21130
# [166]	validation-rmse:23.19759
# [167]	validation-rmse:23.20100
# [168]	validation-rmse:23.20087
# [169]	validation-rmse:23.18981
# [170]	validation-rmse:23.18307
# [171]	validation-rmse:23.18219
# [172]	validation-rmse:23.17630
# [173]	validation-rmse:23.18180
# [174]	validation-rmse:23.18148
# [175]	validation-rmse:23.18262
# [176]	validation-rmse:23.17799
# [177]	validation-rmse:23.17864
# [178]	validation-rmse:23.17447
# [179]	validation-rmse:23.17548
# [180]	validation-rmse:23.16466
# [181]	validation-rmse:23.16385
# [182]	validation-rmse:23.16040
# [183]	validation-rmse:23.16327
# [184]	validation-rmse:23.15286
# [185]	validation-rmse:23.15703
# [186]	validation-rmse:23.15246
# [187]	validation-rmse:23.15436
# [188]	validation-rmse:23.14433
# [189]	validation-rmse:23.13624
# [190]	validation-rmse:23.13816
# [191]	validation-rmse:23.14131
# [192]	validation-rmse:23.14233
# [193]	validation-rmse:23.14515
# [194]	validation-rmse:23.14673
# [195]	validation-rmse:23.14613
# [196]	validation-rmse:23.14411
# [197]	validation-rmse:23.14270
# [198]	validation-rmse:23.13831
# [199]	validation-rmse:23.13708
# [200]	validation-rmse:23.14140
# [201]	validation-rmse:23.14185
# [202]	validation-rmse:23.13795
# [203]	validation-rmse:23.12953
# [204]	validation-rmse:23.12848
# [205]	validation-rmse:23.12450
# [206]	validation-rmse:23.12061
# [207]	validation-rmse:23.12061
# [208]	validation-rmse:23.11856
# [209]	validation-rmse:23.12042
# [210]	validation-rmse:23.11997
# [211]	validation-rmse:23.11872
# [212]	validation-rmse:23.11033
# [213]	validation-rmse:23.11064
# [214]	validation-rmse:23.10703
# [215]	validation-rmse:23.10677
# [216]	validation-rmse:23.10462
# [217]	validation-rmse:23.10526
# [218]	validation-rmse:23.10767
# [219]	validation-rmse:23.10240
# [220]	validation-rmse:23.10540
# [221]	validation-rmse:23.10806
# [222]	validation-rmse:23.11248
# [223]	validation-rmse:23.10588
# [224]	validation-rmse:23.10570
# [225]	validation-rmse:23.10668
# [226]	validation-rmse:23.11109
# [227]	validation-rmse:23.11205
# [228]	validation-rmse:23.11008
# [229]	validation-rmse:23.10522
# [230]	validation-rmse:23.10865
# [231]	validation-rmse:23.10527
# [232]	validation-rmse:23.09879
# [233]	validation-rmse:23.09866
# [234]	validation-rmse:23.09900
# [235]	validation-rmse:23.09301
# [236]	validation-rmse:23.09206
# [237]	validation-rmse:23.09419
# [238]	validation-rmse:23.09048
# [239]	validation-rmse:23.08938
# [240]	validation-rmse:23.09098
# [241]	validation-rmse:23.08815
# [242]	validation-rmse:23.08935
# [243]	validation-rmse:23.08870
# [244]	validation-rmse:23.08521
# [245]	validation-rmse:23.08699
# [246]	validation-rmse:23.08852
# [247]	validation-rmse:23.08791
# [248]	validation-rmse:23.08859
# [249]	validation-rmse:23.08322
# [250]	validation-rmse:23.08416
# [251]	validation-rmse:23.08188
# [252]	validation-rmse:23.08226
# [253]	validation-rmse:23.08201
# [254]	validation-rmse:23.08633
# [255]	validation-rmse:23.08491
# [256]	validation-rmse:23.08683
# [257]	validation-rmse:23.08484
# [258]	validation-rmse:23.08469
# [259]	validation-rmse:23.08872
# [260]	validation-rmse:23.08635
# [261]	validation-rmse:23.08740
# [262]	validation-rmse:23.08756
# [263]	validation-rmse:23.08684
# [264]	validation-rmse:23.08252
# [265]	validation-rmse:23.08506
# [266]	validation-rmse:23.08407
# [267]	validation-rmse:23.08143
# [268]	validation-rmse:23.08255
# [269]	validation-rmse:23.08151
# [270]	validation-rmse:23.08143
# [271]	validation-rmse:23.08171
# [272]	validation-rmse:23.08234
# [273]	validation-rmse:23.08684
# [274]	validation-rmse:23.08799
# [275]	validation-rmse:23.08820
# [276]	validation-rmse:23.09021
# [277]	validation-rmse:23.09048
# [278]	validation-rmse:23.09170
# [279]	validation-rmse:23.09316
# [280]	validation-rmse:23.08909
# [281]	validation-rmse:23.09188
# [282]	validation-rmse:23.09199
# [283]	validation-rmse:23.09158
# [284]	validation-rmse:23.09224
# [285]	validation-rmse:23.09284
# [286]	validation-rmse:23.09449
# [287]	validation-rmse:23.09165
# [288]	validation-rmse:23.09402
# [289]	validation-rmse:23.09428
# [290]	validation-rmse:23.09618
# [291]	validation-rmse:23.09716
# [292]	validation-rmse:23.09633
# [293]	validation-rmse:23.09464
# [294]	validation-rmse:23.09379
# [295]	validation-rmse:23.09324
# [296]	validation-rmse:23.09459
# [297]	validation-rmse:23.09377
# [298]	validation-rmse:23.09133
# [299]	validation-rmse:23.09150
# [300]	validation-rmse:23.09099
# [301]	validation-rmse:23.09073
# [302]	validation-rmse:23.09159
# [303]	validation-rmse:23.09057
# [304]	validation-rmse:23.08935
# [305]	validation-rmse:23.08959
# [306]	validation-rmse:23.08890
# [307]	validation-rmse:23.08893
# [308]	validation-rmse:23.08803
# [309]	validation-rmse:23.08622
# [310]	validation-rmse:23.08974
# [311]	validation-rmse:23.09135
# [312]	validation-rmse:23.09240
# [313]	validation-rmse:23.09484
# [314]	validation-rmse:23.09256
# [315]	validation-rmse:23.09432
# [316]	validation-rmse:23.09526
# [317]	validation-rmse:23.09660
# [0]	validation-rmse:33.17726
# [1]	validation-rmse:31.94305
# [2]	validation-rmse:31.54430
# [3]	validation-rmse:31.69051
# [4]	validation-rmse:31.77412
# [5]	validation-rmse:31.88625
# [6]	validation-rmse:31.79444
# [7]	validation-rmse:31.72119
# [8]	validation-rmse:31.39439
# [9]	validation-rmse:31.25309
# [10]	validation-rmse:31.13255
# [11]	validation-rmse:31.10391
# [12]	validation-rmse:30.91774
# [13]	validation-rmse:30.89595
# [14]	validation-rmse:30.87382
# [15]	validation-rmse:30.86446
# [16]	validation-rmse:30.80505
# [17]	validation-rmse:30.82333
# [18]	validation-rmse:30.77729
# [19]	validation-rmse:30.71985
# [20]	validation-rmse:30.72253
# [21]	validation-rmse:30.72670
# [22]	validation-rmse:30.78105
# [23]	validation-rmse:30.77043
# [24]	validation-rmse:30.78190
# [25]	validation-rmse:30.77907
# [26]	validation-rmse:30.77027
# [27]	validation-rmse:30.76787
# [28]	validation-rmse:30.76341
# [29]	validation-rmse:30.74362
# [30]	validation-rmse:30.72153
# [31]	validation-rmse:30.69440
# [32]	validation-rmse:30.72730
# [33]	validation-rmse:30.71603
# [34]	validation-rmse:30.73020
# [35]	validation-rmse:30.73267
# [36]	validation-rmse:30.73733
# [37]	validation-rmse:30.75537
# [38]	validation-rmse:30.74464
# [39]	validation-rmse:30.74792
# [40]	validation-rmse:30.74197
# [41]	validation-rmse:30.74863
# [42]	validation-rmse:30.74220
# [43]	validation-rmse:30.74505
# [44]	validation-rmse:30.74566
# [45]	validation-rmse:30.73476
# [46]	validation-rmse:30.73252
# [47]	validation-rmse:30.73179
# [48]	validation-rmse:30.74022
# [49]	validation-rmse:30.73389
# [50]	validation-rmse:30.72673
# [51]	validation-rmse:30.73025
# [52]	validation-rmse:30.73527
# [53]	validation-rmse:30.73976
# [54]	validation-rmse:30.73304
# [55]	validation-rmse:30.72956
# [56]	validation-rmse:30.72922
# [57]	validation-rmse:30.72582
# [58]	validation-rmse:30.72867
# [59]	validation-rmse:30.73170
# [60]	validation-rmse:30.73552
# [61]	validation-rmse:30.73545
# [62]	validation-rmse:30.73391
# [63]	validation-rmse:30.73922
# [64]	validation-rmse:30.74072
# [65]	validation-rmse:30.73835
# [66]	validation-rmse:30.73509
# [67]	validation-rmse:30.73912
# [68]	validation-rmse:30.73922
# [69]	validation-rmse:30.74212
# [70]	validation-rmse:30.73989
# [71]	validation-rmse:30.73945
# [72]	validation-rmse:30.74139
# [73]	validation-rmse:30.74055
# [74]	validation-rmse:30.74082
# [75]	validation-rmse:30.73991
# [76]	validation-rmse:30.73945
# [77]	validation-rmse:30.74024
# [78]	validation-rmse:30.74321
# [79]	validation-rmse:30.74563
# [80]	validation-rmse:30.74365
# [81]	validation-rmse:30.74329
# [0]	validation-rmse:33.26212
# [1]	validation-rmse:33.92959
# [2]	validation-rmse:34.01335
# [3]	validation-rmse:34.26917
# [4]	validation-rmse:34.34930
# [5]	validation-rmse:34.36745
# [6]	validation-rmse:34.38348
# [7]	validation-rmse:34.38822
# [8]	validation-rmse:34.37557
# [9]	validation-rmse:34.38015
# [10]	validation-rmse:34.38163
# [11]	validation-rmse:34.38153
# [12]	validation-rmse:34.38111
# [13]	validation-rmse:34.38121
# [14]	validation-rmse:34.38159
# [15]	validation-rmse:34.38155
# [16]	validation-rmse:34.38152
# [17]	validation-rmse:34.38102
# [18]	validation-rmse:34.38089
# [19]	validation-rmse:34.38080
# [20]	validation-rmse:34.38093
# [21]	validation-rmse:34.38097
# [22]	validation-rmse:34.38104
# [23]	validation-rmse:34.38104
# [24]	validation-rmse:34.38104
# [25]	validation-rmse:34.38104
# [26]	validation-rmse:34.38104
# [27]	validation-rmse:34.38104
# [28]	validation-rmse:34.38104
# [29]	validation-rmse:34.38104
# [30]	validation-rmse:34.38104
# [31]	validation-rmse:34.38104
# [32]	validation-rmse:34.38104
# [33]	validation-rmse:34.38104
# [34]	validation-rmse:34.38104
# [35]	validation-rmse:34.38104
# [36]	validation-rmse:34.38104
# [37]	validation-rmse:34.38104
# [38]	validation-rmse:34.38104
# [39]	validation-rmse:34.38104
# [40]	validation-rmse:34.38104
# [41]	validation-rmse:34.38104
# [42]	validation-rmse:34.38104
# [43]	validation-rmse:34.38104
# [44]	validation-rmse:34.38104
# [45]	validation-rmse:34.38104
# [46]	validation-rmse:34.38104
# [47]	validation-rmse:34.38104
# [48]	validation-rmse:34.38104
# [49]	validation-rmse:34.38104
# [50]	validation-rmse:34.38104
# [0]	validation-rmse:36.22409
# [1]	validation-rmse:34.81742
# [2]	validation-rmse:33.67599
# [3]	validation-rmse:32.56988
# [4]	validation-rmse:31.67184
# [5]	validation-rmse:30.83273
# [6]	validation-rmse:30.15595
# [7]	validation-rmse:29.66009
# [8]	validation-rmse:29.16101
# [9]	validation-rmse:28.71194
# [10]	validation-rmse:28.30153
# [11]	validation-rmse:27.98220
# [12]	validation-rmse:27.71423
# [13]	validation-rmse:27.39899
# [14]	validation-rmse:27.20586
# [15]	validation-rmse:27.02195
# [16]	validation-rmse:26.79254
# [17]	validation-rmse:26.68116
# [18]	validation-rmse:26.56706
# [19]	validation-rmse:26.57637
# [20]	validation-rmse:26.46614
# [21]	validation-rmse:26.33356
# [22]	validation-rmse:26.23746
# [23]	validation-rmse:26.14031
# [24]	validation-rmse:26.07265
# [25]	validation-rmse:25.99576
# [26]	validation-rmse:26.05618
# [27]	validation-rmse:26.01891
# [28]	validation-rmse:26.08318
# [29]	validation-rmse:25.98452
# [30]	validation-rmse:25.93098
# [31]	validation-rmse:25.87622
# [32]	validation-rmse:25.87342
# [33]	validation-rmse:25.77200
# [34]	validation-rmse:25.72522
# [35]	validation-rmse:25.69214
# [36]	validation-rmse:25.62392
# [37]	validation-rmse:25.54206
# [38]	validation-rmse:25.51162
# [39]	validation-rmse:25.41756
# [40]	validation-rmse:25.38212
# [41]	validation-rmse:25.37379
# [42]	validation-rmse:25.32406
# [43]	validation-rmse:25.32773
# [44]	validation-rmse:25.28485
# [45]	validation-rmse:25.22141
# [46]	validation-rmse:25.24858
# [47]	validation-rmse:25.18777
# [48]	validation-rmse:25.22013
# [49]	validation-rmse:25.17659
# [50]	validation-rmse:25.16519
# [51]	validation-rmse:25.12325
# [52]	validation-rmse:25.09780
# [53]	validation-rmse:25.10833
# ...
# [20]	validation-rmse:29.88683
# [21]	validation-rmse:29.84265
# [22]	validation-rmse:29.68684
# [23]	validation-rmse:29.70905
# [24]	validation-rmse:29.61858
# [25]	validation-rmse:29.66544
# [26]	validation-rmse:29.70720
# [27]	validation-rmse:29.62464
# [28]	validation-rmse:29.59411
# [29]	validation-rmse:29.51260
# [30]	validation-rmse:29.52986
# [31]	validation-rmse:29.55241
# [32]	validation-rmse:29.55143
# [33]	validation-rmse:29.54043
# [34]	validation-rmse:29.49912
# [35]	validation-rmse:29.52736
# [36]	validation-rmse:29.51062
# [37]	validation-rmse:29.50228
# [38]	validation-rmse:29.50793
# [39]	validation-rmse:29.50247
# [40]	validation-rmse:29.46037
# [41]	validation-rmse:29.47092
# [42]	validation-rmse:29.47225
# [43]	validation-rmse:29.46508
# [44]	validation-rmse:29.44169
# [45]	validation-rmse:29.43824
# [46]	validation-rmse:29.44414
# [47]	validation-rmse:29.43347
# [48]	validation-rmse:29.42904
# [49]	validation-rmse:29.42337
# [50]	validation-rmse:29.39853
# [51]	validation-rmse:29.42856
# [52]	validation-rmse:29.41306
# [53]	validation-rmse:29.42000
# [54]	validation-rmse:29.41289
# [55]	validation-rmse:29.41442
# [56]	validation-rmse:29.41455
# [57]	validation-rmse:29.40628
# [58]	validation-rmse:29.39820
# [59]	validation-rmse:29.39955
# [60]	validation-rmse:29.41670
# [61]	validation-rmse:29.40980
# [62]	validation-rmse:29.39333
# [63]	validation-rmse:29.39099
# [64]	validation-rmse:29.40328
# [65]	validation-rmse:29.40696
# [66]	validation-rmse:29.41202
# [67]	validation-rmse:29.40648
# [68]	validation-rmse:29.40676
# [69]	validation-rmse:29.39804
# [70]	validation-rmse:29.39536
# [71]	validation-rmse:29.39687
# [72]	validation-rmse:29.38484
# [73]	validation-rmse:29.38344
# [74]	validation-rmse:29.38691
# [75]	validation-rmse:29.39427
# [76]	validation-rmse:29.39724
# [77]	validation-rmse:29.39160
# [78]	validation-rmse:29.38930
# [79]	validation-rmse:29.38860
# [80]	validation-rmse:29.39109
# [81]	validation-rmse:29.39795
# [82]	validation-rmse:29.40085
# [83]	validation-rmse:29.40329
# [84]	validation-rmse:29.40628
# [85]	validation-rmse:29.40798
# [86]	validation-rmse:29.40977
# [87]	validation-rmse:29.40971
# [88]	validation-rmse:29.40794
# [89]	validation-rmse:29.40893
# [90]	validation-rmse:29.41424
# [91]	validation-rmse:29.41407
# [92]	validation-rmse:29.41546
# [93]	validation-rmse:29.41613
# [94]	validation-rmse:29.42088
# [95]	validation-rmse:29.42564
# [96]	validation-rmse:29.42658
# [97]	validation-rmse:29.42998
# [98]	validation-rmse:29.43083
# [99]	validation-rmse:29.43288
# [100]	validation-rmse:29.43198
# [101]	validation-rmse:29.43265
# [102]	validation-rmse:29.43211
# [103]	validation-rmse:29.43208
# [104]	validation-rmse:29.43308
# [105]	validation-rmse:29.43338
# [106]	validation-rmse:29.43391
# [107]	validation-rmse:29.43303
# [108]	validation-rmse:29.43199
# [109]	validation-rmse:29.43706
# [110]	validation-rmse:29.43665
# [111]	validation-rmse:29.43707
# [112]	validation-rmse:29.43340
# [113]	validation-rmse:29.43267
# [114]	validation-rmse:29.43370
# [115]	validation-rmse:29.43601
# [116]	validation-rmse:29.43755
# [117]	validation-rmse:29.43829
# [118]	validation-rmse:29.43938
# [119]	validation-rmse:29.43826
# [120]	validation-rmse:29.44008
# [121]	validation-rmse:29.44193
# [122]	validation-rmse:29.44401
# [123]	validation-rmse:29.44462
# [0]	validation-rmse:36.76078
# [1]	validation-rmse:35.80662
# [2]	validation-rmse:34.94683
# [3]	validation-rmse:34.20749
# [4]	validation-rmse:33.59423
# [5]	validation-rmse:33.02295
# [6]	validation-rmse:32.61192
# [7]	validation-rmse:32.22322
# [8]	validation-rmse:31.88082
# [9]	validation-rmse:31.58275
# [10]	validation-rmse:31.36298
# [11]	validation-rmse:31.11311
# [12]	validation-rmse:30.96231
# [13]	validation-rmse:30.80302
# [14]	validation-rmse:30.67212
# [15]	validation-rmse:30.57975
# [16]	validation-rmse:30.47347
# [17]	validation-rmse:30.43846
# [18]	validation-rmse:30.41358
# [19]	validation-rmse:30.40469
# [20]	validation-rmse:30.33724
# [21]	validation-rmse:30.28635
# [22]	validation-rmse:30.24531
# [23]	validation-rmse:30.25359
# [24]	validation-rmse:30.22099
# [25]	validation-rmse:30.20611
# [26]	validation-rmse:30.18035
# [27]	validation-rmse:30.16500
# [28]	validation-rmse:30.18503
# [29]	validation-rmse:30.16311
# [30]	validation-rmse:30.17721
# [31]	validation-rmse:30.16645
# [32]	validation-rmse:30.14204
# [33]	validation-rmse:30.17293
# [34]	validation-rmse:30.14982
# [35]	validation-rmse:30.14498
# [36]	validation-rmse:30.14848
# [37]	validation-rmse:30.14485
# [38]	validation-rmse:30.13773
# [39]	validation-rmse:30.13372
# [40]	validation-rmse:30.14719
# [41]	validation-rmse:30.16425
# [42]	validation-rmse:30.16508
# [43]	validation-rmse:30.18626
# [44]	validation-rmse:30.18743
# [45]	validation-rmse:30.18557
# [46]	validation-rmse:30.18933
# [47]	validation-rmse:30.20178
# [48]	validation-rmse:30.20913
# [49]	validation-rmse:30.21133
# [50]	validation-rmse:30.22998
# [51]	validation-rmse:30.23750
# [52]	validation-rmse:30.22536
# [53]	validation-rmse:30.23317
# [54]	validation-rmse:30.23913
# [55]	validation-rmse:30.25106
# [56]	validation-rmse:30.25531
# [57]	validation-rmse:30.25444
# [58]	validation-rmse:30.26929
# [59]	validation-rmse:30.26902
# [60]	validation-rmse:30.27338
# [61]	validation-rmse:30.26885
# [62]	validation-rmse:30.26983
# [63]	validation-rmse:30.28015
# [64]	validation-rmse:30.28984
# [65]	validation-rmse:30.28462
# [66]	validation-rmse:30.29731
# [67]	validation-rmse:30.30513
# [68]	validation-rmse:30.31015
# [69]	validation-rmse:30.31301
# [70]	validation-rmse:30.32177
# [71]	validation-rmse:30.32272
# [72]	validation-rmse:30.32920
# [73]	validation-rmse:30.32652
# [74]	validation-rmse:30.33774
# [75]	validation-rmse:30.33835
# [76]	validation-rmse:30.34388
# [77]	validation-rmse:30.35026
# [78]	validation-rmse:30.35004
# [79]	validation-rmse:30.35288
# [80]	validation-rmse:30.35155
# [81]	validation-rmse:30.35053
# [82]	validation-rmse:30.34659
# [83]	validation-rmse:30.34382
# [84]	validation-rmse:30.34867
# [85]	validation-rmse:30.34748
# [86]	validation-rmse:30.34750
# [87]	validation-rmse:30.34648
# [88]	validation-rmse:30.35234
# [89]	validation-rmse:30.35626
# 100%|██████████| 50/50 [13:09<00:00, 15.79s/trial, best loss: 22.891421444830254]

# %%
mlflow.xgboost.autolog(disable=True)

with mlflow.start_run():
    
    mlflow.set_tag("developer", "oliver")
    mlflow.log_param("train-data-path", "datasets/airbnb-listings-may.csv")
    mlflow.log_param("val-data-path", "datasets/airbnb-listings-june.csv")
    
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    best_params = {
        'learning_rate': 0.09585355369315604,
        'max_depth': 30,
        'min_child_weight': 1.060597050922164,
        'objective': 'reg:linear',
        'reg_alpha': 0.018060244040060163,
        'reg_lambda': 0.011658731377413597,
        'seed': 42
    }

    mlflow.log_params(best_params)

    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=1000,
        evals=[(valid, 'validation')],
        early_stopping_rounds=50
    )

    y_pred = booster.predict(valid)
    rmse = root_mean_squared_error(y_val, y_pred)
    mlflow.log_metric("rmse", rmse)

    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)
        
    mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")
    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
# [0]	validation-rmse:36.04995
# [1]	validation-rmse:34.64846
# [2]	validation-rmse:33.48183
# [3]	validation-rmse:32.69584
# [4]	validation-rmse:32.04908
# [5]	validation-rmse:31.54993
# [6]	validation-rmse:31.18200
# [7]	validation-rmse:30.96145
# [8]	validation-rmse:30.72317
# [9]	validation-rmse:30.49955
# [10]	validation-rmse:30.40726
# [11]	validation-rmse:30.32743
# [12]	validation-rmse:30.26791
# [13]	validation-rmse:30.29633
# [14]	validation-rmse:30.26653
# [15]	validation-rmse:30.24214
# [16]	validation-rmse:30.21247
# [17]	validation-rmse:30.23653
# [18]	validation-rmse:30.23235
# [19]	validation-rmse:30.22032
# [20]	validation-rmse:30.26356
# [21]	validation-rmse:30.27924
# [22]	validation-rmse:30.27724
# [23]	validation-rmse:30.29739
# [24]	validation-rmse:30.29717
# [25]	validation-rmse:30.30737
# [26]	validation-rmse:30.30606
# [27]	validation-rmse:30.30539
# [28]	validation-rmse:30.30691
# [29]	validation-rmse:30.31768
# [30]	validation-rmse:30.31806
# [31]	validation-rmse:30.31691
# [32]	validation-rmse:30.31476
# [33]	validation-rmse:30.32713
# [34]	validation-rmse:30.35138
# [35]	validation-rmse:30.35984
# [36]	validation-rmse:30.37629
# [37]	validation-rmse:30.39718
# [38]	validation-rmse:30.41456
# [39]	validation-rmse:30.42724
# [40]	validation-rmse:30.44125
# [41]	validation-rmse:30.44933
# [42]	validation-rmse:30.45981
# [43]	validation-rmse:30.47413
# [44]	validation-rmse:30.47205
# [45]	validation-rmse:30.47504
# [46]	validation-rmse:30.47019
# [47]	validation-rmse:30.46464
# [48]	validation-rmse:30.46381
# [49]	validation-rmse:30.46171
# [50]	validation-rmse:30.45652
# [51]	validation-rmse:30.45405
# [52]	validation-rmse:30.45693
# [53]	validation-rmse:30.45640
# [54]	validation-rmse:30.45371
# [55]	validation-rmse:30.44680
# [56]	validation-rmse:30.44294
# [57]	validation-rmse:30.44043
# [58]	validation-rmse:30.43846
# [59]	validation-rmse:30.43090
# [60]	validation-rmse:30.43347
# [61]	validation-rmse:30.43525
# [62]	validation-rmse:30.43323
# [63]	validation-rmse:30.42928
# [64]	validation-rmse:30.42308
# [65]	validation-rmse:30.42243
# [66]	validation-rmse:30.41497

# %% [markdown]
# ### Other

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR

mlflow.sklearn.autolog()

for model_class in (RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, LinearSVR):

    with mlflow.start_run():

        mlflow.set_tag("developer", "oliver")
        mlflow.log_param("train-data-path", "datasets/airbnb-listings-may.csv")
        mlflow.log_param("val-data-path", "datasets/airbnb-listings-june.csv")
        mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

        mlmodel = model_class()
        mlmodel.fit(X_train, y_train)

        y_pred = mlmodel.predict(X_val)
        rmse = root_mean_squared_error(y_val, y_pred)
        mlflow.log_metric("rmse", rmse)
# Out:
# 2024/07/28 18:50:28 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of sklearn. If you encounter errors during autologging, try upgrading / downgrading sklearn to a supported version, or try upgrading MLflow.
# 2024/07/28 18:50:28 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# 2024/07/28 18:50:31 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# 2024/07/28 18:50:33 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# 2024/07/28 18:50:36 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
